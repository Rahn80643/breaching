# %% [markdown]
# # Inverting Gradients - How easy is it to break privacy in federated learning?

# %% [markdown]
# This notebook shows an example for a **small-batch image gradient inversion** as described in "Inverting Gradients - How easy is it to break privacy in federated learning?". The setting is a trained ResNet-18 and the federated learning algorithm is **fedAVG**.
#
# Paper URL: https://proceedings.neurips.cc/paper/2020/hash/c4ede56bbd98819ae6112b20ac6bf145-Abstract.html

# %% [markdown]
# This notebook can replicate the experiments in Fig.5 and Tab. 2 of this paper.

# %% [markdown]
# #### Abstract
# The idea of federated learning is to collaboratively train a neural network on a server. Each user receives the current weights of the network and in turns sends parameter updates (gradients) based on local data. This protocol has been designed not only to train neural networks data-efficiently, but also to provide privacy benefits for users, as their input data remains on device and only parameter gradients are shared. But how secure is sharing parameter gradients? Previous attacks have provided a false sense of security, by succeeding only in contrived settings - even for a single image. However, by exploiting a magnitude-invariant loss along with optimization strategies based on adversarial attacks, we show that is is actually possible to faithfully reconstruct images at high resolution from the knowledge of their parameter gradients, and demonstrate that such a break of privacy is possible even for trained deep networks. We analyze the effects of architecture as well as parameters on the difficulty of reconstructing an input image and prove that any input to a fully connected layer can be reconstructed analytically independent of the remaining architecture. Finally we discuss settings encountered in practice and show that even averaging gradients over several iterations or several images does not protect the user's privacy in federated learning applications.

# %% [markdown]
# ### Startup

# %%
try:
    import breaching
except ModuleNotFoundError:
    # You only really need this safety net if you want to run these notebooks directly in the examples directory
    # Don't worry about this if you installed the package or moved the notebook to the main directory.
    import os; os.chdir("..")
    import breaching
    
    
import torch
# %load_ext autoreload
# %autoreload 2

# Redirects logs directly into the jupyter notebook
import logging, sys
logging.basicConfig(level=logging.INFO, handlers=[logging.StreamHandler(sys.stdout)], format='%(message)s')
logger = logging.getLogger()

# %% [markdown]
# ### Initialize cfg object and system setup:

# %% [markdown]
# This will load the full configuration object. This includes the configuration for the use case and threat model as `cfg.case` and the hyperparameters and implementation of the attack as `cfg.attack`. All parameters can be modified below, or overriden with `overrides=` as if they were cmd-line arguments.

# %%
cfg = breaching.get_config(overrides=["case=4_fedavg_small_scale_FL", "case/data=CIFAR10"])
          
device = torch.device(f'cuda:0') if torch.cuda.is_available() else torch.device('cpu')
torch.backends.cudnn.benchmark = cfg.case.impl.benchmark
setup = dict(device=device, dtype=getattr(torch, cfg.case.impl.dtype))
setup
# Out:
# Investigating use case fedavg_small_scale with server type honest_but_curious.
# {'device': device(type='cuda', index=0), 'dtype': torch.float32}

# %% [markdown]
# ### Modify config options here

# %% [markdown]
# You can use `.attribute` access to modify any of these configurations for the attack, or the case:

# %%
cfg.case.data.partition="random"
cfg.case.model='resnet18'

cfg.case.user.provide_labels = True

# These settings govern the total amount of user data and how it is used over multiple local update steps:
cfg.case.user.num_data_points = 10 # should be the same as #users to avoid error (incompatitle #reconstrcted data and #user)
cfg.case.user.num_local_updates = 10 #4
cfg.case.user.num_data_per_local_update_step = 10 #2


# Total variation regularization needs to be smaller on CIFAR-10:
cfg.attack.regularization.total_variation.scale = 1e-3

# %% [markdown]
# ### Instantiate all parties

# %% [markdown]
# The following lines generate "server, "user" and "attacker" objects and print an overview of their configurations.

# %%
user, server, model, loss_fn = breaching.cases.construct_case(cfg.case, setup)
attacker = breaching.attacks.prepare_attack(server.model, server.loss, cfg.attack, setup)
breaching.utils.overview(server, user, attacker)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Model architecture resnet18 loaded with 11,173,962 parameters and 9,620 buffers.
# Overall this is a data ratio of     364:1 for target shape [10, 3, 32, 32] given that num_queries=1.
# User (of type UserMultiStep) with settings:
#     Number of data points: 10
#
#     Threat model:
#     User provides labels: True
#     User provides buffers: False
#     User provides number of data points: True
#
#     Data:
#     Dataset: CIFAR10
#     user: 0
#
#
#     Local FL Setup:
#         Number of local update steps: 10
#         Data per local update step: 10
#         Local learning rate: 0.001
#
#         Threat model:
#         Share these hyperparams to server: False
#
#
#     Number of aggregated users: 10
# Server (of type HonestServer) with settings:
#     Threat model: Honest-but-curious
#     Number of planned queries: 1
#     Has external/public data: False
#
#     Model:
#         model specification: resnet18
#         model state: default
#         public buffers: True
#
#     Secrets: {}
#
# Attacker (of type OptimizationBasedAttacker) with settings:
#     Hyperparameter Template: invertinggradients
#
#     Objective: Cosine Similarity with scale=1.0 and task reg=0.0
#     Regularizers: Total Variation, scale=0.001. p=1 q=1.
#     Augmentations:
#
#     Optimization Setup:
#         optimizer: adam
#         signed: hard
#         step_size: 0.1
#         boxed: True
#         max_iterations: 24000
#         step_size_decay: step-lr
#         langevin_noise: 0.0
#         warmup: 0
#         grad_clip: None
#         callback: 100

# %% [markdown]
# ### Simulate an attacked FL protocol

# %% [markdown]
# This exchange is a simulation of a single query in a federated learning protocol. The server sends out a `server_payload` and the user computes an update based on their private local data. This user update is `shared_data` and contains, for example, the parameter gradient of the model in the simplest case. `true_user_data` is also returned by `.compute_local_updates`, but of course not forwarded to the server or attacker and only used for (our) analysis.

# %%
server_payload = server.distribute_payload()
shared_data, true_user_data = user.compute_local_updates(server_payload)
# Out:
# Computing user update on user 0 in model mode: eval.
# Computing user update on user 1 in model mode: eval.
# Computing user update on user 2 in model mode: eval.
# Computing user update on user 3 in model mode: eval.
# Computing user update on user 4 in model mode: eval.
# Computing user update on user 5 in model mode: eval.
# Computing user update on user 6 in model mode: eval.
# Computing user update on user 7 in model mode: eval.
# Computing user update on user 8 in model mode: eval.
# Computing user update on user 9 in model mode: eval.

# %%
user.plot(true_user_data)

# %% [markdown]
# ### Reconstruct user data:

# %% [markdown]
# Now we launch the attack, reconstructing user data based on only the `server_payload` and the `shared_data`.
#
# You can interrupt the computation early to see a partial solution.

# %%
reconstructed_user_data, stats = attacker.reconstruct([server_payload], [shared_data], {}, dryrun=cfg.dryrun)
# Out:
# | It: 1 | Rec. loss: 1.5582 |  Task loss: 2.3764 | T: 0.20s
# | It: 101 | Rec. loss: 0.1580 |  Task loss: 2.0225 | T: 12.60s
# | It: 201 | Rec. loss: 0.1492 |  Task loss: 2.0020 | T: 6.16s
# | It: 301 | Rec. loss: 0.1474 |  Task loss: 1.9908 | T: 6.14s
# | It: 401 | Rec. loss: 0.1486 |  Task loss: 1.9958 | T: 6.24s
# | It: 501 | Rec. loss: 0.1434 |  Task loss: 1.9956 | T: 6.26s
# | It: 601 | Rec. loss: 0.1422 |  Task loss: 1.9851 | T: 6.38s
# | It: 701 | Rec. loss: 0.1420 |  Task loss: 1.9807 | T: 6.16s
# | It: 801 | Rec. loss: 0.1460 |  Task loss: 1.9727 | T: 6.23s
# | It: 901 | Rec. loss: 0.1452 |  Task loss: 1.9745 | T: 6.21s
# | It: 1001 | Rec. loss: 0.1424 |  Task loss: 1.9726 | T: 6.17s
# | It: 1101 | Rec. loss: 0.1421 |  Task loss: 1.9741 | T: 6.28s
# | It: 1201 | Rec. loss: 0.1392 |  Task loss: 1.9709 | T: 6.25s
# | It: 1301 | Rec. loss: 0.1410 |  Task loss: 1.9721 | T: 6.12s
# | It: 1401 | Rec. loss: 0.1443 |  Task loss: 1.9705 | T: 6.10s
# | It: 1501 | Rec. loss: 0.1387 |  Task loss: 1.9788 | T: 6.12s
# | It: 1601 | Rec. loss: 0.1379 |  Task loss: 1.9693 | T: 6.09s
# | It: 1701 | Rec. loss: 0.1362 |  Task loss: 1.9698 | T: 6.11s
# | It: 1801 | Rec. loss: 0.1362 |  Task loss: 1.9708 | T: 6.09s
# | It: 1901 | Rec. loss: 0.1379 |  Task loss: 1.9661 | T: 6.05s
# | It: 2001 | Rec. loss: 0.1385 |  Task loss: 1.9632 | T: 6.07s
# | It: 2101 | Rec. loss: 0.1371 |  Task loss: 1.9553 | T: 6.08s
# | It: 2201 | Rec. loss: 0.1377 |  Task loss: 1.9561 | T: 6.18s
# | It: 2301 | Rec. loss: 0.1404 |  Task loss: 1.9616 | T: 6.24s
# | It: 2401 | Rec. loss: 0.1407 |  Task loss: 1.9640 | T: 6.09s
# | It: 2501 | Rec. loss: 0.1425 |  Task loss: 1.9684 | T: 6.09s
# | It: 2601 | Rec. loss: 0.1416 |  Task loss: 1.9647 | T: 6.23s
# | It: 2701 | Rec. loss: 0.1454 |  Task loss: 1.9677 | T: 6.27s
# | It: 2801 | Rec. loss: 0.1422 |  Task loss: 1.9705 | T: 6.29s
# | It: 2901 | Rec. loss: 0.1393 |  Task loss: 1.9719 | T: 6.30s
# | It: 3001 | Rec. loss: 0.1393 |  Task loss: 1.9767 | T: 6.19s
# | It: 3101 | Rec. loss: 0.1403 |  Task loss: 1.9760 | T: 6.17s
# | It: 3201 | Rec. loss: 0.1399 |  Task loss: 1.9792 | T: 6.28s
# | It: 3301 | Rec. loss: 0.1369 |  Task loss: 1.9808 | T: 6.15s
# | It: 3401 | Rec. loss: 0.1405 |  Task loss: 1.9787 | T: 6.29s
# | It: 3501 | Rec. loss: 0.1385 |  Task loss: 1.9730 | T: 6.26s
# | It: 3601 | Rec. loss: 0.1399 |  Task loss: 1.9795 | T: 6.15s
# | It: 3701 | Rec. loss: 0.1405 |  Task loss: 1.9749 | T: 6.16s
# | It: 3801 | Rec. loss: 0.1419 |  Task loss: 1.9756 | T: 6.31s
# | It: 3901 | Rec. loss: 0.1394 |  Task loss: 1.9785 | T: 6.25s
# | It: 4001 | Rec. loss: 0.1414 |  Task loss: 1.9808 | T: 6.13s
# | It: 4101 | Rec. loss: 0.1405 |  Task loss: 1.9789 | T: 6.20s
# | It: 4201 | Rec. loss: 0.1408 |  Task loss: 1.9807 | T: 6.13s
# | It: 4301 | Rec. loss: 0.1416 |  Task loss: 1.9830 | T: 6.14s
# | It: 4401 | Rec. loss: 0.1416 |  Task loss: 1.9844 | T: 6.11s
# | It: 4501 | Rec. loss: 0.1405 |  Task loss: 1.9800 | T: 6.18s
# | It: 4601 | Rec. loss: 0.1429 |  Task loss: 1.9819 | T: 6.25s
# | It: 4701 | Rec. loss: 0.1428 |  Task loss: 1.9827 | T: 6.31s
# | It: 4801 | Rec. loss: 0.1398 |  Task loss: 1.9868 | T: 6.40s
# | It: 4901 | Rec. loss: 0.1400 |  Task loss: 1.9863 | T: 6.27s
# | It: 5001 | Rec. loss: 0.1414 |  Task loss: 1.9787 | T: 6.28s
# | It: 5101 | Rec. loss: 0.1421 |  Task loss: 1.9837 | T: 6.21s
# | It: 5201 | Rec. loss: 0.1441 |  Task loss: 1.9811 | T: 6.20s
# | It: 5301 | Rec. loss: 0.1436 |  Task loss: 1.9759 | T: 6.16s
# | It: 5401 | Rec. loss: 0.1403 |  Task loss: 1.9758 | T: 6.11s
# | It: 5501 | Rec. loss: 0.1419 |  Task loss: 1.9700 | T: 6.25s
# | It: 5601 | Rec. loss: 0.1414 |  Task loss: 1.9711 | T: 6.10s
# | It: 5701 | Rec. loss: 0.1445 |  Task loss: 1.9669 | T: 6.17s
# | It: 5801 | Rec. loss: 0.1418 |  Task loss: 1.9706 | T: 6.19s
# | It: 5901 | Rec. loss: 0.1436 |  Task loss: 1.9648 | T: 6.15s
# | It: 6001 | Rec. loss: 0.1431 |  Task loss: 1.9660 | T: 6.11s
# | It: 6101 | Rec. loss: 0.1423 |  Task loss: 1.9681 | T: 6.18s
# | It: 6201 | Rec. loss: 0.1446 |  Task loss: 1.9691 | T: 6.13s
# | It: 6301 | Rec. loss: 0.1413 |  Task loss: 1.9671 | T: 6.18s
# | It: 6401 | Rec. loss: 0.1400 |  Task loss: 1.9713 | T: 6.24s
# | It: 6501 | Rec. loss: 0.1407 |  Task loss: 1.9699 | T: 6.34s
# | It: 6601 | Rec. loss: 0.1401 |  Task loss: 1.9699 | T: 6.28s
# | It: 6701 | Rec. loss: 0.1413 |  Task loss: 1.9655 | T: 6.20s
# | It: 6801 | Rec. loss: 0.1415 |  Task loss: 1.9647 | T: 6.19s
# | It: 6901 | Rec. loss: 0.1427 |  Task loss: 1.9698 | T: 6.18s
# | It: 7001 | Rec. loss: 0.1384 |  Task loss: 1.9719 | T: 6.20s
# | It: 7101 | Rec. loss: 0.1394 |  Task loss: 1.9653 | T: 6.21s
# | It: 7201 | Rec. loss: 0.1395 |  Task loss: 1.9655 | T: 6.22s
# | It: 7301 | Rec. loss: 0.1392 |  Task loss: 1.9672 | T: 6.29s
# | It: 7401 | Rec. loss: 0.1366 |  Task loss: 1.9660 | T: 6.40s
# | It: 7501 | Rec. loss: 0.1388 |  Task loss: 1.9681 | T: 6.29s
# | It: 7601 | Rec. loss: 0.1397 |  Task loss: 1.9712 | T: 6.34s
# | It: 7701 | Rec. loss: 0.1389 |  Task loss: 1.9727 | T: 6.27s
# | It: 7801 | Rec. loss: 0.1407 |  Task loss: 1.9734 | T: 6.19s
# | It: 7901 | Rec. loss: 0.1396 |  Task loss: 1.9719 | T: 6.19s
# | It: 8001 | Rec. loss: 0.1411 |  Task loss: 1.9732 | T: 6.16s
# | It: 8101 | Rec. loss: 0.1389 |  Task loss: 1.9713 | T: 6.18s
# | It: 8201 | Rec. loss: 0.1417 |  Task loss: 1.9730 | T: 6.19s
# | It: 8301 | Rec. loss: 0.1417 |  Task loss: 1.9748 | T: 6.25s
# | It: 8401 | Rec. loss: 0.1412 |  Task loss: 1.9742 | T: 6.25s
# | It: 8501 | Rec. loss: 0.1400 |  Task loss: 1.9818 | T: 6.33s
# | It: 8601 | Rec. loss: 0.1418 |  Task loss: 1.9777 | T: 6.20s
# | It: 8701 | Rec. loss: 0.1392 |  Task loss: 1.9801 | T: 6.27s
# | It: 8801 | Rec. loss: 0.1414 |  Task loss: 1.9737 | T: 6.07s
# | It: 8901 | Rec. loss: 0.1404 |  Task loss: 1.9727 | T: 6.38s
# | It: 9001 | Rec. loss: 0.1428 |  Task loss: 1.9746 | T: 6.33s
# | It: 9101 | Rec. loss: 0.1397 |  Task loss: 1.9591 | T: 6.42s
# | It: 9201 | Rec. loss: 0.1386 |  Task loss: 1.9610 | T: 6.16s
# | It: 9301 | Rec. loss: 0.1392 |  Task loss: 1.9589 | T: 6.21s
# | It: 9401 | Rec. loss: 0.1394 |  Task loss: 1.9602 | T: 6.21s
# | It: 9501 | Rec. loss: 0.1375 |  Task loss: 1.9599 | T: 6.32s
# | It: 9601 | Rec. loss: 0.1395 |  Task loss: 1.9610 | T: 6.24s
# | It: 9701 | Rec. loss: 0.1374 |  Task loss: 1.9579 | T: 6.15s
# | It: 9801 | Rec. loss: 0.1372 |  Task loss: 1.9597 | T: 6.27s
# | It: 9901 | Rec. loss: 0.1384 |  Task loss: 1.9583 | T: 6.15s
# | It: 10001 | Rec. loss: 0.1383 |  Task loss: 1.9569 | T: 6.19s
# | It: 10101 | Rec. loss: 0.1381 |  Task loss: 1.9567 | T: 6.21s
# | It: 10201 | Rec. loss: 0.1389 |  Task loss: 1.9541 | T: 6.31s
# | It: 10301 | Rec. loss: 0.1363 |  Task loss: 1.9555 | T: 6.16s
# | It: 10401 | Rec. loss: 0.1375 |  Task loss: 1.9589 | T: 6.21s
# | It: 10501 | Rec. loss: 0.1392 |  Task loss: 1.9575 | T: 6.34s
# | It: 10601 | Rec. loss: 0.1395 |  Task loss: 1.9560 | T: 6.22s
# | It: 10701 | Rec. loss: 0.1388 |  Task loss: 1.9569 | T: 6.24s
# | It: 10801 | Rec. loss: 0.1386 |  Task loss: 1.9592 | T: 6.22s
# | It: 10901 | Rec. loss: 0.1392 |  Task loss: 1.9574 | T: 6.28s
# | It: 11001 | Rec. loss: 0.1369 |  Task loss: 1.9566 | T: 6.28s
# | It: 11101 | Rec. loss: 0.1391 |  Task loss: 1.9564 | T: 6.13s
# | It: 11201 | Rec. loss: 0.1382 |  Task loss: 1.9559 | T: 6.11s
# | It: 11301 | Rec. loss: 0.1375 |  Task loss: 1.9553 | T: 6.13s
# | It: 11401 | Rec. loss: 0.1384 |  Task loss: 1.9556 | T: 6.19s
# | It: 11501 | Rec. loss: 0.1377 |  Task loss: 1.9555 | T: 6.21s
# | It: 11601 | Rec. loss: 0.1384 |  Task loss: 1.9549 | T: 6.25s
# | It: 11701 | Rec. loss: 0.1376 |  Task loss: 1.9560 | T: 6.25s
# | It: 11801 | Rec. loss: 0.1360 |  Task loss: 1.9584 | T: 6.36s
# | It: 11901 | Rec. loss: 0.1371 |  Task loss: 1.9569 | T: 6.31s
# | It: 12001 | Rec. loss: 0.1371 |  Task loss: 1.9570 | T: 6.27s
# | It: 12101 | Rec. loss: 0.1389 |  Task loss: 1.9566 | T: 6.22s
# | It: 12201 | Rec. loss: 0.1381 |  Task loss: 1.9551 | T: 6.15s
# | It: 12301 | Rec. loss: 0.1370 |  Task loss: 1.9543 | T: 6.25s
# | It: 12401 | Rec. loss: 0.1373 |  Task loss: 1.9557 | T: 6.26s
# | It: 12501 | Rec. loss: 0.1368 |  Task loss: 1.9553 | T: 6.24s
# | It: 12601 | Rec. loss: 0.1379 |  Task loss: 1.9542 | T: 6.25s
# | It: 12701 | Rec. loss: 0.1371 |  Task loss: 1.9541 | T: 6.23s
# | It: 12801 | Rec. loss: 0.1375 |  Task loss: 1.9538 | T: 6.24s
# | It: 12901 | Rec. loss: 0.1379 |  Task loss: 1.9549 | T: 6.21s
# | It: 13001 | Rec. loss: 0.1366 |  Task loss: 1.9561 | T: 6.14s
# | It: 13101 | Rec. loss: 0.1377 |  Task loss: 1.9544 | T: 6.33s
# | It: 13201 | Rec. loss: 0.1369 |  Task loss: 1.9556 | T: 6.32s
# | It: 13301 | Rec. loss: 0.1371 |  Task loss: 1.9568 | T: 6.49s
# | It: 13401 | Rec. loss: 0.1368 |  Task loss: 1.9553 | T: 6.35s
# | It: 13501 | Rec. loss: 0.1381 |  Task loss: 1.9548 | T: 6.35s
# | It: 13601 | Rec. loss: 0.1372 |  Task loss: 1.9550 | T: 6.46s
# | It: 13701 | Rec. loss: 0.1375 |  Task loss: 1.9558 | T: 6.36s
# | It: 13801 | Rec. loss: 0.1365 |  Task loss: 1.9546 | T: 6.31s
# | It: 13901 | Rec. loss: 0.1370 |  Task loss: 1.9559 | T: 6.19s
# | It: 14001 | Rec. loss: 0.1365 |  Task loss: 1.9555 | T: 6.22s
# | It: 14101 | Rec. loss: 0.1373 |  Task loss: 1.9526 | T: 6.27s
# | It: 14201 | Rec. loss: 0.1396 |  Task loss: 1.9535 | T: 6.30s
# | It: 14301 | Rec. loss: 0.1373 |  Task loss: 1.9548 | T: 6.26s
# | It: 14401 | Rec. loss: 0.1388 |  Task loss: 1.9555 | T: 6.24s
# | It: 14501 | Rec. loss: 0.1367 |  Task loss: 1.9552 | T: 6.22s
# | It: 14601 | Rec. loss: 0.1375 |  Task loss: 1.9551 | T: 6.19s
# | It: 14701 | Rec. loss: 0.1379 |  Task loss: 1.9569 | T: 6.26s
# | It: 14801 | Rec. loss: 0.1387 |  Task loss: 1.9570 | T: 6.39s
# | It: 14901 | Rec. loss: 0.1377 |  Task loss: 1.9568 | T: 6.21s
# | It: 15001 | Rec. loss: 0.1372 |  Task loss: 1.9559 | T: 6.22s
# | It: 15101 | Rec. loss: 0.1373 |  Task loss: 1.9555 | T: 6.15s
# | It: 15201 | Rec. loss: 0.1374 |  Task loss: 1.9547 | T: 6.21s
# | It: 15301 | Rec. loss: 0.1375 |  Task loss: 1.9548 | T: 6.26s
# | It: 15401 | Rec. loss: 0.1363 |  Task loss: 1.9547 | T: 6.20s
# | It: 15501 | Rec. loss: 0.1369 |  Task loss: 1.9550 | T: 6.19s
# | It: 15601 | Rec. loss: 0.1386 |  Task loss: 1.9554 | T: 6.26s
# | It: 15701 | Rec. loss: 0.1378 |  Task loss: 1.9556 | T: 6.24s
# | It: 15801 | Rec. loss: 0.1379 |  Task loss: 1.9558 | T: 6.32s
# | It: 15901 | Rec. loss: 0.1391 |  Task loss: 1.9558 | T: 6.34s
# | It: 16001 | Rec. loss: 0.1373 |  Task loss: 1.9561 | T: 6.23s
# | It: 16101 | Rec. loss: 0.1368 |  Task loss: 1.9562 | T: 6.25s
# | It: 16201 | Rec. loss: 0.1374 |  Task loss: 1.9563 | T: 6.18s
# | It: 16301 | Rec. loss: 0.1386 |  Task loss: 1.9567 | T: 6.18s
# | It: 16401 | Rec. loss: 0.1385 |  Task loss: 1.9565 | T: 6.20s
# | It: 16501 | Rec. loss: 0.1390 |  Task loss: 1.9564 | T: 6.30s
# | It: 16601 | Rec. loss: 0.1387 |  Task loss: 1.9562 | T: 6.26s
# | It: 16701 | Rec. loss: 0.1383 |  Task loss: 1.9557 | T: 6.26s
# | It: 16801 | Rec. loss: 0.1385 |  Task loss: 1.9555 | T: 6.21s
# | It: 16901 | Rec. loss: 0.1373 |  Task loss: 1.9550 | T: 6.27s
# | It: 17001 | Rec. loss: 0.1387 |  Task loss: 1.9551 | T: 6.22s
# | It: 17101 | Rec. loss: 0.1385 |  Task loss: 1.9550 | T: 6.17s
# | It: 17201 | Rec. loss: 0.1380 |  Task loss: 1.9542 | T: 6.18s
# | It: 17301 | Rec. loss: 0.1381 |  Task loss: 1.9540 | T: 6.27s
# | It: 17401 | Rec. loss: 0.1380 |  Task loss: 1.9538 | T: 6.18s
# | It: 17501 | Rec. loss: 0.1375 |  Task loss: 1.9538 | T: 6.21s
# | It: 17601 | Rec. loss: 0.1382 |  Task loss: 1.9543 | T: 6.19s
# | It: 17701 | Rec. loss: 0.1381 |  Task loss: 1.9542 | T: 6.25s
# | It: 17801 | Rec. loss: 0.1379 |  Task loss: 1.9541 | T: 6.22s
# | It: 17901 | Rec. loss: 0.1379 |  Task loss: 1.9542 | T: 6.36s
# | It: 18001 | Rec. loss: 0.1382 |  Task loss: 1.9540 | T: 6.24s
# | It: 18101 | Rec. loss: 0.1377 |  Task loss: 1.9537 | T: 6.17s
# | It: 18201 | Rec. loss: 0.1375 |  Task loss: 1.9536 | T: 6.17s
# | It: 18301 | Rec. loss: 0.1378 |  Task loss: 1.9541 | T: 6.21s
# | It: 18401 | Rec. loss: 0.1382 |  Task loss: 1.9543 | T: 6.21s
# | It: 18501 | Rec. loss: 0.1389 |  Task loss: 1.9545 | T: 6.24s
# | It: 18601 | Rec. loss: 0.1394 |  Task loss: 1.9547 | T: 6.32s
# | It: 18701 | Rec. loss: 0.1383 |  Task loss: 1.9547 | T: 6.33s
# | It: 18801 | Rec. loss: 0.1380 |  Task loss: 1.9549 | T: 6.36s
# | It: 18901 | Rec. loss: 0.1383 |  Task loss: 1.9544 | T: 6.28s
# | It: 19001 | Rec. loss: 0.1379 |  Task loss: 1.9547 | T: 6.10s
# | It: 19101 | Rec. loss: 0.1386 |  Task loss: 1.9540 | T: 6.21s
# | It: 19201 | Rec. loss: 0.1388 |  Task loss: 1.9542 | T: 6.16s
# | It: 19301 | Rec. loss: 0.1393 |  Task loss: 1.9549 | T: 6.22s
# | It: 19401 | Rec. loss: 0.1384 |  Task loss: 1.9554 | T: 6.16s
# | It: 19501 | Rec. loss: 0.1400 |  Task loss: 1.9558 | T: 6.15s
# | It: 19601 | Rec. loss: 0.1384 |  Task loss: 1.9559 | T: 6.27s
# | It: 19701 | Rec. loss: 0.1374 |  Task loss: 1.9554 | T: 6.37s
# | It: 19801 | Rec. loss: 0.1383 |  Task loss: 1.9550 | T: 6.27s
# | It: 19901 | Rec. loss: 0.1384 |  Task loss: 1.9548 | T: 6.34s
# | It: 20001 | Rec. loss: 0.1382 |  Task loss: 1.9550 | T: 6.26s
# | It: 20101 | Rec. loss: 0.1388 |  Task loss: 1.9553 | T: 6.26s
# | It: 20201 | Rec. loss: 0.1380 |  Task loss: 1.9552 | T: 6.20s
# | It: 20301 | Rec. loss: 0.1391 |  Task loss: 1.9550 | T: 6.14s
# | It: 20401 | Rec. loss: 0.1380 |  Task loss: 1.9546 | T: 6.15s
# | It: 20501 | Rec. loss: 0.1372 |  Task loss: 1.9542 | T: 6.18s
# | It: 20601 | Rec. loss: 0.1376 |  Task loss: 1.9541 | T: 6.26s
# | It: 20701 | Rec. loss: 0.1386 |  Task loss: 1.9540 | T: 6.24s
# | It: 20801 | Rec. loss: 0.1377 |  Task loss: 1.9540 | T: 6.34s
# | It: 20901 | Rec. loss: 0.1379 |  Task loss: 1.9537 | T: 6.29s
# | It: 21001 | Rec. loss: 0.1372 |  Task loss: 1.9537 | T: 6.14s
# | It: 21101 | Rec. loss: 0.1373 |  Task loss: 1.9537 | T: 6.31s
# | It: 21201 | Rec. loss: 0.1388 |  Task loss: 1.9536 | T: 6.17s
# | It: 21301 | Rec. loss: 0.1383 |  Task loss: 1.9536 | T: 6.12s
# | It: 21401 | Rec. loss: 0.1377 |  Task loss: 1.9536 | T: 6.25s
# | It: 21501 | Rec. loss: 0.1378 |  Task loss: 1.9536 | T: 6.21s
# | It: 21601 | Rec. loss: 0.1384 |  Task loss: 1.9535 | T: 6.33s
# | It: 21701 | Rec. loss: 0.1370 |  Task loss: 1.9533 | T: 6.20s
# | It: 21801 | Rec. loss: 0.1375 |  Task loss: 1.9532 | T: 6.21s
# | It: 21901 | Rec. loss: 0.1377 |  Task loss: 1.9532 | T: 6.19s
# | It: 22001 | Rec. loss: 0.1380 |  Task loss: 1.9532 | T: 6.16s
# | It: 22101 | Rec. loss: 0.1377 |  Task loss: 1.9532 | T: 6.23s
# | It: 22201 | Rec. loss: 0.1370 |  Task loss: 1.9531 | T: 6.34s
# | It: 22301 | Rec. loss: 0.1379 |  Task loss: 1.9531 | T: 6.40s
# | It: 22401 | Rec. loss: 0.1376 |  Task loss: 1.9530 | T: 6.15s
# | It: 22501 | Rec. loss: 0.1376 |  Task loss: 1.9530 | T: 6.15s
# | It: 22601 | Rec. loss: 0.1379 |  Task loss: 1.9530 | T: 6.09s
# | It: 22701 | Rec. loss: 0.1367 |  Task loss: 1.9530 | T: 6.13s
# | It: 22801 | Rec. loss: 0.1373 |  Task loss: 1.9530 | T: 6.16s
# | It: 22901 | Rec. loss: 0.1376 |  Task loss: 1.9531 | T: 6.18s
# | It: 23001 | Rec. loss: 0.1385 |  Task loss: 1.9531 | T: 6.28s
# | It: 23101 | Rec. loss: 0.1371 |  Task loss: 1.9530 | T: 6.22s
# | It: 23201 | Rec. loss: 0.1374 |  Task loss: 1.9530 | T: 6.22s
# | It: 23301 | Rec. loss: 0.1372 |  Task loss: 1.9530 | T: 6.19s
# | It: 23401 | Rec. loss: 0.1376 |  Task loss: 1.9530 | T: 6.11s
# | It: 23501 | Rec. loss: 0.1372 |  Task loss: 1.9530 | T: 6.23s
# | It: 23601 | Rec. loss: 0.1371 |  Task loss: 1.9531 | T: 6.26s
# | It: 23701 | Rec. loss: 0.1371 |  Task loss: 1.9531 | T: 6.26s
# | It: 23801 | Rec. loss: 0.1389 |  Task loss: 1.9531 | T: 6.27s
# | It: 23901 | Rec. loss: 0.1390 |  Task loss: 1.9532 | T: 6.32s
# | It: 24000 | Rec. loss: 0.1385 |  Task loss: 1.9533 | T: 6.29s
# Optimal candidate solution with rec. loss 0.1346 selected.

# %% [markdown]
# Next we'll evaluate metrics, comparing the `reconstructed_user_data` to the `true_user_data`.

# %%
metrics = breaching.analysis.report(reconstructed_user_data, true_user_data, [server_payload], 
                                    server.model, order_batch=True, compute_full_iip=False, 
                                    cfg_case=cfg.case, setup=setup)
# Out:
# Starting evaluations for attack effectiveness report...
# Files already downloaded and verified
# METRICS: | MSE: 0.1377 | PSNR: 9.26 | FMSE: 6.2834e-01 | LPIPS: 0.40|
#  R-PSNR: 10.58 | IIP-pixel: 0.00% | SSIM: 0.1900 | max R-PSNR: 14.40 | max SSIM: 0.2811 | Label Acc: 50.00%

# %% [markdown]
# And finally, we also plot the reconstructed data:

# %%
user.plot(reconstructed_user_data)

# %% [markdown]
# ### Notes:
# * If labels are unknown, then a robust label recovery algorithm has to be used that does not count label repetitions due to shifts after local updates.
